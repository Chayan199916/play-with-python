# %%
from bokeh.plotting import figure, output_file, show
import pandas as pd

# %%
tempdf = pd.read_csv('working1.csv', parse_dates = ['Year'])
p = figure(width = 800, height = 250, x_axis_type = 'datetime')
p.line(tempdf['Year'], tempdf['SO2'], color = 'blue', alpha = 0.5)
output_file('polution_data.html')
show(p)

# %%
tempdf = df.groupby(['Year']).sum().reset_index()

# %%
tempdf.head()
# Out:
#    Year  Air Temperature  Pressure Station Level  Pressure Mean Sea Level  \
# 0  2013      9578.126841           275428.608547            275547.139264
# 1  2014      9684.925561           275655.877041            275774.809521
# 2  2015      9829.790252           275813.621341            275931.356237
# 3  2016     10019.988400           276325.818129            276442.786350
# 4  2017      9703.632599           275584.750694            275702.871390
#
#    Relative Humidity  Horizontal Visibility  Dew Point Temperature     PM2.5  \
# 0       27223.691435            1044.077096            7586.766700  12995.50
# 1       26924.214916             985.400348            7613.040327  13818.00
# 2       27381.163325             990.616016            7888.525151  12264.50
# 3       27480.744371            1016.229971            8063.113974  24344.25
# 4       27362.551704            1068.437345            7761.068115  25084.50
#
# ...

# %%
df = pd.read_csv('merged_new.csv')

# %%
df['Year']
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2013
# 4       2013
#         ...
# 2367    2019
# 2368    2019
# 2369    2019
# 2370    2019
# 2371    2019
# Name: Year, Length: 2372, dtype: int64

# %%
tempdf.to_csv('working1.csv')
